# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
df = pd.read_csv('../data/advertising.csv', index_col=0)
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
sns.pairplot(df, x_vars=['TV', 'Radio', 'Newspaper'], y_vars='Sales', height=4, kind='reg')

# %%
# create model
feature_cols = ['TV', 'Radio', 'Newspaper']
X = df[feature_cols]
y = df.Sales

model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# predict
x_input = [[300, 0, 0], [0, 300, 0], [0, 0, 300], [100, 200, 200], [100, 200, 0]]
predict = model.predict(x_input)
predict
# Out:
# /Users/thitiwasnupan/work/workspace/machine_learning101/venv/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([16.66828301, 59.49789444,  2.62764146, 45.01385869, 45.2213573 ])
